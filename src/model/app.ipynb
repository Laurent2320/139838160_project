# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Csv file_path to read
# !pwd
file_path = '../../data/euromillions_202002.csv' 

# Read the data into a DataFrame
encoding = 'latin-1' 
df = pd.read_csv(file_path, delimiter=';',encoding=encoding)

df.head()
df.info()
df.memory_usage(deep=True)
# Out:
# /home/sterstc/code/STERSTC/139838160_project/src/app
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415 entries, 0 to 414
# Data columns (total 76 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   annee_numero_de_tirage                               415 non-null    int64
#  1   jour_de_tirage                                       415 non-null    object
#  2   date_de_tirage                                       415 non-null    object
#  3   numéro_de_tirage_dans_le_cycle                       415 non-null    object
#  4   date_de_forclusion                                   415 non-null    object
#  5   boule_1                                              415 non-null    int64
#  6   boule_2                                              415 non-null    int64
#  7   boule_3                                              415 non-null    int64
#  8   boule_4                                              415 non-null    int64
#  9   boule_5                                              415 non-null    int64
#  10  etoile_1                                             415 non-null    int64
#  11  etoile_2                                             415 non-null    int64
#  12  boules_gagnantes_en_ordre_croissant                  415 non-null    object
#  13  etoiles_gagnantes_en_ordre_croissant                 415 non-null    object
#  14  nombre_de_gagnant_au_rang1_Euro_Millions_en_france   415 non-null    int64
#  15  nombre_de_gagnant_au_rang1_Euro_Millions_en_europe   415 non-null    int64
#  16  rapport_du_rang1_Euro_Millions                       415 non-null    int64
#  17  nombre_de_gagnant_au_rang2_Euro_Millions_en_france   415 non-null    int64
#  18  nombre_de_gagnant_au_rang2_Euro_Millions_en_europe   415 non-null    int64
#  19  rapport_du_rang2_Euro_Millions                       415 non-null    object
#  20  nombre_de_gagnant_au_rang3_Euro_Millions_en_france   415 non-null    int64
#  21  nombre_de_gagnant_au_rang3_Euro_Millions_en_europe   415 non-null    int64
#  22  rapport_du_rang3_Euro_Millions                       415 non-null    object
#  23  nombre_de_gagnant_au_rang4_Euro_Millions_en_france   415 non-null    int64
#  24  nombre_de_gagnant_au_rang4_Euro_Millions_en_europe   415 non-null    int64
#  25  rapport_du_rang4_Euro_Millions                       415 non-null    object
#  26  nombre_de_gagnant_au_rang5_Euro_Millions_en_france   415 non-null    int64
#  27  nombre_de_gagnant_au_rang5_Euro_Millions_en_europe   415 non-null    int64
#  28  rapport_du_rang5_Euro_Millions                       415 non-null    object
#  29  nombre_de_gagnant_au_rang6_Euro_Millions_en_france   415 non-null    int64
#  30  nombre_de_gagnant_au_rang6_Euro_Millions_en_europe   415 non-null    int64
#  31  rapport_du_rang6_Euro_Millions                       415 non-null    object
#  32  nombre_de_gagnant_au_rang7_Euro_Millions_en_france   415 non-null    int64
#  33  nombre_de_gagnant_au_rang7_Euro_Millions_en_europe   415 non-null    int64
#  34  rapport_du_rang7_Euro_Millions                       415 non-null    object
#  35  nombre_de_gagnant_au_rang8_Euro_Millions_en_france   415 non-null    int64
#  36  nombre_de_gagnant_au_rang8_Euro_Millions_en_europe   415 non-null    int64
#  37  rapport_du_rang8_Euro_Millions                       415 non-null    object
#  38  nombre_de_gagnant_au_rang9_Euro_Millions_en_france   415 non-null    int64
#  39  nombre_de_gagnant_au_rang9_Euro_Millions_en_europe   415 non-null    int64
#  40  rapport_du_rang9_Euro_Millions                       415 non-null    object
#  41  nombre_de_gagnant_au_rang10_Euro_Millions_en_france  415 non-null    int64
#  42  nombre_de_gagnant_au_rang10_Euro_Millions_en_europe  415 non-null    int64
#  43  rapport_du_rang10_Euro_Millions                      415 non-null    object
#  44  nombre_de_gagnant_au_rang11_Euro_Millions_en_france  415 non-null    int64
#  45  nombre_de_gagnant_au_rang11_Euro_Millions_en_europe  415 non-null    int64
#  46  rapport_du_rang11_Euro_Millions                      415 non-null    object
#  47  nombre_de_gagnant_au_rang12_Euro_Millions_en_france  415 non-null    int64
#  48  nombre_de_gagnant_au_rang12_Euro_Millions_en_europe  415 non-null    int64
#  49  rapport_du_rang12_Euro_Millions                      415 non-null    object
#  50  nombre_de_gagnant_au_rang13_Euro_Millions_en_france  415 non-null    int64
#  51  nombre_de_gagnant_au_rang13_Euro_Millions_en_europe  415 non-null    int64
#  52  rapport_du_rang13_Euro_Millions                      415 non-null    object
#  53  nombre_de_gagnant_au_rang1_Etoile+                   415 non-null    int64
#  54  rapport_du_rang1_Etoile+                             415 non-null    object
#  55  nombre_de_gagnant_au_rang2_Etoile+                   415 non-null    int64
#  56  rapport_du_rang2_Etoile+                             415 non-null    object
#  57  nombre_de_gagnant_au_rang3_Etoile+                   415 non-null    int64
#  58  rapport_du_rang3_Etoile+                             415 non-null    object
#  59  nombre_de_gagnant_au_rang4_Etoile+                   415 non-null    int64
#  60  rapport_du_rang4_Etoile+                             415 non-null    object
#  61  nombre_de_gagnant_au_rang5_Etoile+                   415 non-null    int64
#  62  rapport_du_rang5_Etoile+                             415 non-null    object
#  63  nombre_de_gagnant_au_rang6_Etoile+                   415 non-null    int64
#  64  rapport_du_rang6_Etoile+                             415 non-null    object
#  65  nombre_de_gagnant_au_rang7_Etoile+                   415 non-null    int64
#  66  rapport_du_rang7_Etoile+                             415 non-null    object
#  67  nombre_de_gagnant_au_rang8_Etoile+                   415 non-null    int64
#  68  rapport_du_rang8_Etoile+                             415 non-null    object
#  69  nombre_de_gagnant_au_rang9_Etoile+                   415 non-null    int64
#  70  rapport_du_rang9_Etoile+                             415 non-null    object
#  71  nombre_de_gagnant_au_rang10_Etoile+                  415 non-null    int64
#  72  rapport_du_rang10_Etoile+                            415 non-null    object
#  73  numero_My_Million                                    415 non-null    object
#  74  numero_Tirage_Exceptionnel_Euro_Million              2 non-null      object
#  75  Unnamed: 75                                          0 non-null      float64
# dtypes: float64(1), int64(45), object(30)
# memory usage: 246.5+ KB
# Index                                        128
# annee_numero_de_tirage                      3320
# jour_de_tirage                             26975
# date_de_tirage                             27805
# numéro_de_tirage_dans_le_cycle             24642
#                                            ...
# nombre_de_gagnant_au_rang10_Etoile+         3320
# rapport_du_rang10_Etoile+                  24892
# numero_My_Million                          28220
# numero_Tirage_Exceptionnel_Euro_Million    15730
# Unnamed: 75                                 3320
# Length: 77, dtype: int64

# %%
# Filter columns starting with "boule_" and "etoile_"
selected_columns = [col for col in df.columns if col.startswith(('boule_', 'etoile_'))]
filtered_df = df[selected_columns]

# Display the cleaned and filtered DataFrame
print(filtered_df)
# Out:
#      boule_1  boule_2  boule_3  boule_4  boule_5  etoile_1  etoile_2
# 0         48       23       14       50       39        12         3
# 1         50       27       28       48       44         7        12
# 2         18       21       33       45       10        12         8
# 3         18       16       17       49       45         9        12
# 4         12        9        2       39       40         3         1
# ..       ...      ...      ...      ...      ...       ...       ...
# 410       34       32       11       38       47        10         2
# 411        5       35       20       41       49        10         6
# 412       43       26       24       32       46         6        10
# 413       17       15        9       25       40         9         3
# 414       35       21       33       23       47         6         7
#
# [415 rows x 7 columns]

# %% [markdown]
# Some data visualization

# %%
# Visualize the distribution of "boule_" columns
boule_columns = [col for col in filtered_df.columns if col.startswith('boule_')]
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))
sns.boxplot(data=filtered_df[boule_columns])
plt.title('Distribution of Boule Numbers')
plt.show()

# %%
# Visualize the distribution of "etoile_" columns
etoile_columns = [col for col in filtered_df.columns if col.startswith('etoile_')]
plt.figure(figsize=(8, 6))
sns.countplot(data=filtered_df[etoile_columns].stack(), palette="viridis")
plt.title('Count of Etoile Numbers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 etoile_columns = [col for col in filtered_df.columns if col.startswith('etoile_')]
#       3 plt.figure(figsize=(8, 6))
# ----> 4 sns.countplot(data=filtered_df[etoile_columns].stack(), palette="viridis")
#       5 plt.title('Count of Etoile Numbers')
#       6 plt.show()
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/seaborn/categorical.py:2635, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2632     dodge = p._dodge_needed()
#    2634 if p.var_types.get(p.orient) == "categorical" or not native_scale:
# -> 2635     p.scale_categorical(p.orient, order=order, formatter=formatter)
#    2637 p._attach(ax, log_scale=log_scale)
#    2639 # Deprecations to remove in v0.14.0.
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/seaborn/_base.py:1430, in VectorPlotter.scale_categorical(self, axis, order, formatter)
#    1425 # Get the initial categorical order, which we do before string
#    1426 # conversion to respect the original types of the order list.
#    1427 # Track whether the order is given explicitly so that we can know
#    1428 # whether or not to use the order constructed here downstream
#    1429 self._var_ordered[axis] = order is not None or cat_data.dtype.name == "category"
# -> 1430 order = pd.Index(categorical_order(cat_data, order), name=axis)
#    1432 # Then convert data to strings. This is because in matplotlib,
#    1433 # "categorical" data really mean "string" data, so doing this artists
#    1434 # will be drawn on the categorical axis with a fixed scale.
#    1435 # TODO implement formatter here; check that it returns strings?
#    1436 if formatter is not None:
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/indexes/base.py:544, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     539     if data and all(isinstance(e, tuple) for e in data):
#     540         # we must be all tuples, otherwise don't construct
#     541         # 10697
#     542         from pandas.core.indexes.multi import MultiIndex
# --> 544         return MultiIndex.from_tuples(data, names=name)
#     545 # other iterable of some kind
#     547 if not isinstance(data, (list, tuple)):
#     548     # we allow set/frozenset, which Series/sanitize_array does not, so
#     549     #  cast to list here
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/indexes/multi.py:220, in names_compat.<locals>.new_meth(self_or_cls, *args, **kwargs)
#     217 if "name" in kwargs:
#     218     kwargs["names"] = kwargs.pop("name")
# --> 220 return meth(self_or_cls, *args, **kwargs)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/indexes/multi.py:622, in MultiIndex.from_tuples(cls, tuples, sortorder, names)
#     619     arrs = zip(*tuples)
#     620     arrays = cast(list[Sequence[Hashable]], arrs)
# --> 622 return cls.from_arrays(arrays, sortorder=sortorder, names=names)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/indexes/multi.py:535, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     532 if names is lib.no_default:
#     533     names = [getattr(arr, "name", None) for arr in arrays]
# --> 535 return cls(
#     536     levels=levels,
#     537     codes=codes,
#     538     sortorder=sortorder,
#     539     names=names,
#     540     verify_integrity=False,
#     541 )
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/indexes/multi.py:354, in MultiIndex.__new__(cls, levels, codes, sortorder, names, dtype, copy, name, verify_integrity)
#     351 result._names = [None] * len(levels)
#     352 if names is not None:
#     353     # handles name validation
# --> 354     result._set_names(names)
#     356 if sortorder is not None:
#     357     result.sortorder = int(sortorder)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/indexes/multi.py:1480, in MultiIndex._set_names(self, names, level, validate)
#    1477 # GH 15110
#    1478 # Don't allow a single string for names in a MultiIndex
#    1479 if names is not None and not is_list_like(names):
# -> 1480     raise ValueError("Names should be list-like for a MultiIndex")
#    1481 names = list(names)
#    1483 if validate:
#
# ValueError: Names should be list-like for a MultiIndex

# %%
# Display correlation heatmap
correlation_matrix = filtered_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Display pair plot
sns.pairplot(filtered_df)
plt.suptitle('Pair Plot', y=1.02)
plt.show()

# %%
# Bar chart for the count of unique values in each "boule_" column
plt.figure(figsize=(12, 6))
unique_counts = filtered_df[boule_columns].nunique().sort_values(ascending=False)
sns.barplot(x=unique_counts.index, y=unique_counts.values, palette="viridis")
plt.title('Count of Unique Values in Boule Columns')
plt.xlabel('Boule Columns')
plt.ylabel('Count of Unique Values')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# /tmp/ipykernel_6734/2759395976.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=unique_counts.index, y=unique_counts.values, palette="viridis")
